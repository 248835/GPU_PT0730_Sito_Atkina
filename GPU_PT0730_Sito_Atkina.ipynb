# %%
# !!!IMPORTANT
#
# Use this before using GitHub
# Make sure you have .env with username, repository, git_token and notebook
# saved localy on your Google Drive
#

from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/Colab\ Notebooks/GPU_PT0730_Sito_Atkina

f = open(".env", "r")
username=f.readline().strip().split('=')[1]
repository=f.readline().strip().split('=')[1]
git_token=f.readline().strip().split('=')[1]
f.close()
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/GPU_PT0730_Sito_Atkina

# %%
# Use to commit changes

# uncomment for first time
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git config user.email "24"
# !git config user.name

#!git add .
#!git commit -m "Added basic git commands"

#!git push origin master
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@e31abcca0d88.(none)')
# Everything up-to-date

# %%
# Use to get code from GitHub

# !git pull --rebase origin master
# Out:
# 248835 GPU_PT0730_Sito_Atkina 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

# %%
print("Hello World")
